# %%
import requests
import json
import pandas as pd
import redis
import time
from time import sleep

# %%
data=pd.read_csv('devices 500.csv')

# %%
data.head()
# Out:
#         Device
# 0  30045809762
# 1  30045863686
# 2  30045871507
# 3  30045851442
# 4  30045734622

# %%
red = redis.Redis(
    host='13.235.0.74',
    port=6379,
    db=0,
    )

# %%
url1='https://www.socket.lynktrac.io/api/device_commands'
header1 = {"Content-type": "application/json", "Accept": "*/*"} 
with requests.Session() as s:
    for i in data['Device']:
       
  #dev2=red.hset(i,'card_update','false')
    
            dev3=red.hgetall(i)
            time.sleep(15)
            if dev3[b'card_update']==b'false':
#                 print('Hello')
#             else:
#                 print('bye')
                
                data2={
                "deviceId":i,
                "type": "add_card",
                "attributes": {
                "card_number" : "9002450X9002451X9002452X9002453X90025515"
                }
                }
                r2 = s.post(url =url1, data = json.dumps(data2), headers= header1)
                time.sleep(15)
                dict2 = r2.text
                print(dict2)
                print(dev3[b'card_update'])
                #print(dev3)
                print(i)
                #time.sleep(5)
#             if dev3[b'card_update']==b'true':

#                 #time.sleep(2)
#                 print(dev3[b'card_update'])
#                 print(i)
#                 res = json.loads(dict2)
        
#                 if res['success'] == True:
#                     print
# Out:
# {"message":"Error execute command","success":false}
# b'false'
# 30045734622
# {"message":"Error execute command","success":false}
# b'false'
# 30045874600
# {"message":"Error execute command","success":false}
# b'false'
# 30045874378
# {"message":"Error execute command","success":false}
# b'false'
# 30045747202
# {"message":"Error execute command","success":false}
# b'false'
# 30045734101
# {"message":"Error execute command","success":false}
# b'false'
# 30045694255
# {"message":"Error execute command","success":false}
# b'false'
# 30045811065
# {"message":"Error execute command","success":false}
# b'false'
# 30045752343
# {"message":"Error execute command","success":false}
# b'false'
# 30045803229
# {"message":"Error execute command","success":false}
# b'false'
# 30045753259
# {"message":"Error execute command","success":false}
# b'false'
# 30045691830
# {"message":"Error execute command","success":false}
# b'false'
# 30045691822
# {"message":"Error execute command","success":false}
# b'false'
# 30045685618
# {"message":"Error execute command","success":false}
# b'false'
# 30045849081
# {"message":"Error execute command","success":false}
# b'false'
# 30045856102
# {"message":"Error execute command","success":false}
# b'false'
# 30045810976
# {"message":"Error execute command","success":false}
# b'false'
# 30045779361
# {"message":"Error execute command","success":false}
# b'false'
# 30045810687
# {"message":"Error execute command","success":false}
# b'false'
# 30045823177
# {"message":"Error execute command","success":false}
# b'false'
# 30045880318
# {"message":"Error execute command","success":false}
# b'false'
# 30045747210
# {"message":"Error execute command","success":false}
# b'false'
# 30045864791
# {"message":"Error execute command","success":false}
# b'false'
# 30045740710
# {"message":"Error execute command","success":false}
# b'false'
# 30045725372
# {"message":"Error execute command","success":false}
# b'false'
# 30045729499
# {"message":"Error execute command","success":false}
# b'false'
# 30045815207
# {"message":"Error execute command","success":false}
# b'false'
# 30045794006
# {"message":"Error execute command","success":false}
# b'false'
# 30045814101
# {"message":"Error execute command","success":false}
# b'false'
# 30045817377
# {"message":"Error execute command","success":false}
# b'false'
# 30045812964
# {"message":"Error execute command","success":false}
# b'false'
# 30045858082
# {"message":"Error execute command","success":false}
# b'false'
# 30045876860
# {"message":"success execute command","success":true}
# b'false'
# 30045776748
# {"message":"success execute command","success":true}
# b'false'
# 30045814713
# {"message":"success execute command","success":true}
# b'false'
# 30045857753
# {"message":"Error execute command","success":false}
# b'false'
# 30045869212
# {"message":"success execute command","success":true}
# b'false'
# 30045741429
# {"message":"success execute command","success":true}
# b'false'
# 30045867059
# {"message":"Error execute command","success":false}
# b'false'
# 30045703692
# {"message":"success execute command","success":true}
# b'false'
# 30045806982
# {"message":"success execute command","success":true}
# b'false'
# 30045748283
# {"message":"Error execute command","success":false}
# b'false'
# 30045878502
# {"message":"Error execute command","success":false}
# b'false'
# 30045867331
# {"message":"Error execute command","success":false}
# b'false'
# 30045749489
# {"message":"Error execute command","success":false}
# b'false'
# 30045787422
# {"message":"Error execute command","success":false}
# b'false'
# 30045876738
# {"message":"Error execute command","success":false}
# b'false'
# 30045786051
# {"message":"Error execute command","success":false}
# b'false'
# 30045810117
# {"message":"Error execute command","success":false}
# b'false'
# 30045818375
# {"message":"Error execute command","success":false}
# b'false'
# 30045805307
# {"message":"Error execute command","success":false}
# b'false'
# 30045728525
# {"message":"Error execute command","success":false}
# b'false'
# 30045749364
# {"message":"Error execute command","success":false}
# b'false'
# 30045812998
# {"message":"Error execute command","success":false}
# b'false'
# 30045816056
# {"message":"Error execute command","success":false}
# b'false'
# 30045867356
# {"message":"Error execute command","success":false}
# b'false'
# 30045727303
# {"message":"Error execute command","success":false}
# b'false'
# 30045871978
# {"message":"Error execute command","success":false}
# b'false'
# 30045741445
# {"message":"Error execute command","success":false}
# b'false'
# 30045753200
# {"message":"Error execute command","success":false}
# b'false'
# 30045879799
# {"message":"Error execute command","success":false}
# b'false'
# 30045855369
# {"message":"Error execute command","success":false}
# b'false'
# 30045782944
# {"message":"Error execute command","success":false}
# b'false'
# 30045834752
# {"message":"Error execute command","success":false}
# b'false'
# 30045754406
# {"message":"Error execute command","success":false}
# b'false'
# 30045692127
# {"message":"Error execute command","success":false}
# b'false'
# 30045857126
# {"message":"Error execute command","success":false}
# b'false'
# 30045826816
# {"message":"Error execute command","success":false}
# b'false'
# 30045807105
# {"message":"Error execute command","success":false}
# b'false'
# 30045854339
# {"message":"Error execute command","success":false}
# b'false'
# 30045828978
# {"message":"Error execute command","success":false}
# b'false'
# 30045858215
# {"message":"Error execute command","success":false}
# b'false'
# 30045807337
# {"message":"Error execute command","success":false}
# b'false'
# 30045799682
# {"message":"Error execute command","success":false}
# b'false'
# 30045865657
# {"message":"Error execute command","success":false}
# b'false'
# 30045809853
# {"message":"Error execute command","success":false}
# b'false'
# 30045879807
# {"message":"Error execute command","success":false}
# b'false'
# 30045732386
# {"message":"Error execute command","success":false}
# b'false'
# 30045805539
# {"message":"Error execute command","success":false}
# b'false'
# 30045805141
# {"message":"Error execute command","success":false}
# b'false'
# 30045807717
# {"message":"Error execute command","success":false}
# b'false'
# 30045814135
# {"message":"success execute command","success":true}
# b'false'
# 30045807436
# {"message":"Error execute command","success":false}
# b'false'
# 30045807196
# {"message":"Error execute command","success":false}
# b'false'
# 30045864288
# {"message":"Error execute command","success":false}
# b'false'
# 30045803328
# {"message":"Error execute command","success":false}
# b'false'
# 30045869535
# {"message":"Error execute command","success":false}
# b'false'
# 30045807394
# {"message":"Error execute command","success":false}
# b'false'
# 30045869576
# {"message":"Error execute command","success":false}
# b'false'
# 30045803484
# {"message":"Error execute command","success":false}
# b'false'
# 30045731974
# {"message":"Error execute command","success":false}
# b'false'
# 30045867133
# {"message":"Error execute command","success":false}
# b'false'
# 30045852010
# {"message":"Error execute command","success":false}
# b'false'
# 30045777076
# {"message":"Error execute command","success":false}
# b'false'
# 30045749414
# {"message":"Error execute command","success":false}
# b'false'
# 30045807618
# {"message":"Error execute command","success":false}
# b'false'
# 30045874642
# {"message":"Error execute command","success":false}
# b'false'
# 30045818268
# {"message":"Error execute command","success":false}
# b'false'
# 30045753093
# {"message":"Error execute command","success":false}
# b'false'
# 30045780831
# {"message":"Error execute command","success":false}
# b'false'
# 30045774776
# {"message":"Error execute command","success":false}
# b'false'
# 30045743912
# {"message":"Error execute command","success":false}
# b'false'
# 30045869196
# {"message":"Error execute command","success":false}
# b'false'
# 30045741650
# {"message":"Error execute command","success":false}
# b'false'
# 30045815439
# {"message":"Error execute command","success":false}
# b'false'
# 30045860443
# {"message":"Error execute command","success":false}
# b'false'
# 30045809838
# {"message":"Error execute command","success":false}
# b'false'
# 30045853497
# {"message":"success execute command","success":true}
# b'false'
# 30045799880
# {"message":"Error execute command","success":false}
# b'false'
# 30045737500
# {"message":"Error execute command","success":false}
# b'false'
# 30045826667
# {"message":"Error execute command","success":false}
# b'false'
# 30045817328
# {"message":"Error execute command","success":false}
# b'false'
# 30045810182
# {"message":"Error execute command","success":false}
# b'false'
# 30045807915
# {"message":"Error execute command","success":false}
# b'false'
# 30045726552
# {"message":"Error execute command","success":false}
# b'false'
# 30045874758
# {"message":"Error execute command","success":false}
# b'false'
# 30045803401
# {"message":"Error execute command","success":false}
# b'false'
# 30045870624

# %%
# df = pd.DataFrame(columns=['Device'])
for i in data['Device']:
    dev3=red.hgetall(i)
#     time.sleep(2)
    if dev3[b'card_update']==b'true':
#         df = df.append({'Device':i}, ignore_index=True)

                #time.sleep(2)
                #print(dev3[b'card_update'])
        print(i)
# Out:
# 30045809762
# 30045863686
# 30045871507
# 30045851442
# 30045773190
# 30045862449
# 30045777639
# 30045805448
# 30045810844
